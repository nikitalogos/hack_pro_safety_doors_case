# %%
import os
import open3d as o3d
import numpy as np
import plotly
import json
import sklearn

# %%
# base_dir = '../RES/point_cloud_train/clouds_stereo'
base_dir = '../RES/point_end/clouds_tof'

# %%
for file_name in os.listdir(base_dir):
    file_path = os.path.join(base_dir, file_name)
    cmd = f'unzip {file_path} -d {base_dir}'
    print(cmd)
    os.system(cmd)
# Out:
# unzip ../RES/point_end/clouds_tof/cloud_0_0035.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0039.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0060.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0032.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0073.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0094.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0066.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0081.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0078.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0013.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0050.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0059.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0064.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0090.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0076.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0056.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0045.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0089.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0019.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0061.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0052.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0065.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0023.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0001.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0055.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0004.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0095.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0014.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0038.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0025.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0096.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0072.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0008.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0051.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0005.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0093.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0044.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0015.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0062.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0009.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0069.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0097.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0041.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0099.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0043.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0082.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0057.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0047.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0071.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0030.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0020.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0024.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0011.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0028.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0079.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0087.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0006.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0086.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0085.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0040.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0063.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0053.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0049.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0074.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0007.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0075.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0046.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0100.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0088.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0077.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0021.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0022.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0003.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0058.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0027.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0016.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0033.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0010.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0068.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0067.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0026.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0098.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0083.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0084.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0037.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0042.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0036.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0034.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0054.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0070.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0002.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0031.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0048.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0012.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0018.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0017.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0091.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0029.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0092.pcd.zip -d ../RES/point_end/clouds_tof
# unzip ../RES/point_end/clouds_tof/cloud_0_0080.pcd.zip -d ../RES/point_end/clouds_tof

# %%
for file_name in os.listdir(base_dir):
    if file_name.split('.')[-1] != 'pcd':
        continue
    
    file_path = os.path.join(base_dir, file_name)
    print(file_path)

    points = []
    colors = []
    with open(file_path, 'r') as inf:
        lines = inf.readlines()
        for line in lines[11:]:
            values = line.strip().split(' ')
            point = [float(i) for i in values[:3]]
            color = int(values[3])
#             color = [color >> 16, (color >> 8) & 2**8, color & 2**8]
            color = [(color // 2**24) & 255, (color // 2**16) & 255, (color // 2**8) & 255, color & 255]
            points.append(point)
            colors.append(color)
            
    points_arr = np.array(points)
    colors_arr = np.array(colors, dtype=np.float) / 255
            
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(points_arr)
    pcd.colors = o3d.utility.Vector3dVector(colors_arr[:,:3])
    
    pcd = pcd.voxel_down_sample(voxel_size=0.05)

    o3d.visualization.draw_geometries([pcd])
    
#     viewer = o3d.visualization.Visualizer()
#     viewer.create_window()
#     viewer.add_geometry(pcd)
#     opt = viewer.get_render_option()
#     opt.show_coordinate_frame = True
#     opt.background_color = np.asarray([0.5, 0.5, 0.5])
#     viewer.run()
#     viewer.destroy_window()
        
#     break
# Out:
# ../RES/point_end/clouds_tof/cloud_0_0001.pcd
# ../RES/point_end/clouds_tof/cloud_0_0016.pcd
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-2a37b4e65b8b> in <module>
#      28     pcd = pcd.voxel_down_sample(voxel_size=0.05)
#      29
# ---> 30     o3d.visualization.draw_geometries([pcd])
#      31
#      32 #     viewer = o3d.visualization.Visualizer()
#
# KeyboardInterrupt:

# %%
for file_name in os.listdir(base_dir):
    if file_name.split('.')[-1] != 'pcd':
        continue
        
    out_file_name = str(int(file_name.split('.')[0].split('_')[2]))
    
    file_path = os.path.join(base_dir, file_name)
    print(file_path)

    os.system(f'../scene_analyzer.py -i {file_path} -o jsons/{out_file_name}.json')
# Out:
# ../RES/point_end/clouds_tof/cloud_0_0001.pcd
# ../RES/point_end/clouds_tof/cloud_0_0016.pcd
# ../RES/point_end/clouds_tof/cloud_0_0074.pcd
# ../RES/point_end/clouds_tof/cloud_0_0070.pcd
# ../RES/point_end/clouds_tof/cloud_0_0004.pcd
# ../RES/point_end/clouds_tof/cloud_0_0080.pcd
# ../RES/point_end/clouds_tof/cloud_0_0077.pcd
# ../RES/point_end/clouds_tof/cloud_0_0058.pcd
# ../RES/point_end/clouds_tof/cloud_0_0096.pcd
# ../RES/point_end/clouds_tof/cloud_0_0088.pcd
# ../RES/point_end/clouds_tof/cloud_0_0031.pcd
# ../RES/point_end/clouds_tof/cloud_0_0036.pcd
# ../RES/point_end/clouds_tof/cloud_0_0022.pcd
# ../RES/point_end/clouds_tof/cloud_0_0052.pcd
# ../RES/point_end/clouds_tof/cloud_0_0082.pcd
# ../RES/point_end/clouds_tof/cloud_0_0010.pcd
# ../RES/point_end/clouds_tof/cloud_0_0019.pcd
# ../RES/point_end/clouds_tof/cloud_0_0072.pcd
# ../RES/point_end/clouds_tof/cloud_0_0051.pcd
# ../RES/point_end/clouds_tof/cloud_0_0055.pcd
# ../RES/point_end/clouds_tof/cloud_0_0062.pcd
# ../RES/point_end/clouds_tof/cloud_0_0069.pcd
# ../RES/point_end/clouds_tof/cloud_0_0015.pcd
# ../RES/point_end/clouds_tof/cloud_0_0065.pcd
# ../RES/point_end/clouds_tof/cloud_0_0090.pcd
# ../RES/point_end/clouds_tof/cloud_0_0038.pcd
# ../RES/point_end/clouds_tof/cloud_0_0093.pcd
# ../RES/point_end/clouds_tof/cloud_0_0085.pcd
# ../RES/point_end/clouds_tof/cloud_0_0026.pcd
# ../RES/point_end/clouds_tof/cloud_0_0002.pcd
# ../RES/point_end/clouds_tof/cloud_0_0057.pcd
# ../RES/point_end/clouds_tof/cloud_0_0048.pcd
# ../RES/point_end/clouds_tof/cloud_0_0083.pcd
# ../RES/point_end/clouds_tof/cloud_0_0030.pcd
# ../RES/point_end/clouds_tof/cloud_0_0028.pcd
# ../RES/point_end/clouds_tof/cloud_0_0034.pcd
# ../RES/point_end/clouds_tof/cloud_0_0050.pcd
# ../RES/point_end/clouds_tof/cloud_0_0023.pcd
# ../RES/point_end/clouds_tof/cloud_0_0047.pcd
# ../RES/point_end/clouds_tof/cloud_0_0045.pcd
# ../RES/point_end/clouds_tof/cloud_0_0079.pcd
# ../RES/point_end/clouds_tof/cloud_0_0035.pcd
# ../RES/point_end/clouds_tof/cloud_0_0066.pcd
# ../RES/point_end/clouds_tof/cloud_0_0033.pcd
# ../RES/point_end/clouds_tof/cloud_0_0084.pcd
# ../RES/point_end/clouds_tof/cloud_0_0064.pcd
# ../RES/point_end/clouds_tof/cloud_0_0054.pcd
# ../RES/point_end/clouds_tof/cloud_0_0094.pcd
# ../RES/point_end/clouds_tof/cloud_0_0067.pcd
# ../RES/point_end/clouds_tof/cloud_0_0011.pcd
# ../RES/point_end/clouds_tof/cloud_0_0092.pcd
# ../RES/point_end/clouds_tof/cloud_0_0006.pcd
# ../RES/point_end/clouds_tof/cloud_0_0032.pcd
# ../RES/point_end/clouds_tof/cloud_0_0040.pcd
# ../RES/point_end/clouds_tof/cloud_0_0049.pcd
# ../RES/point_end/clouds_tof/cloud_0_0043.pcd
# ../RES/point_end/clouds_tof/cloud_0_0044.pcd
# ../RES/point_end/clouds_tof/cloud_0_0013.pcd
# ../RES/point_end/clouds_tof/cloud_0_0014.pcd
# ../RES/point_end/clouds_tof/cloud_0_0012.pcd
# ../RES/point_end/clouds_tof/cloud_0_0039.pcd
# ../RES/point_end/clouds_tof/cloud_0_0041.pcd
# ../RES/point_end/clouds_tof/cloud_0_0061.pcd
# ../RES/point_end/clouds_tof/cloud_0_0095.pcd
# ../RES/point_end/clouds_tof/cloud_0_0003.pcd
# ../RES/point_end/clouds_tof/cloud_0_0097.pcd
# ../RES/point_end/clouds_tof/cloud_0_0053.pcd
# ../RES/point_end/clouds_tof/cloud_0_0025.pcd
# ../RES/point_end/clouds_tof/cloud_0_0056.pcd
# ../RES/point_end/clouds_tof/cloud_0_0029.pcd
# ../RES/point_end/clouds_tof/cloud_0_0060.pcd
# ../RES/point_end/clouds_tof/cloud_0_0081.pcd
# ../RES/point_end/clouds_tof/cloud_0_0020.pcd
# ../RES/point_end/clouds_tof/cloud_0_0099.pcd
# ../RES/point_end/clouds_tof/cloud_0_0075.pcd
# ../RES/point_end/clouds_tof/cloud_0_0046.pcd
# ../RES/point_end/clouds_tof/cloud_0_0098.pcd
# ../RES/point_end/clouds_tof/cloud_0_0008.pcd
# ../RES/point_end/clouds_tof/cloud_0_0005.pcd
# ../RES/point_end/clouds_tof/cloud_0_0037.pcd
# ../RES/point_end/clouds_tof/cloud_0_0068.pcd
# ../RES/point_end/clouds_tof/cloud_0_0009.pcd
# ../RES/point_end/clouds_tof/cloud_0_0063.pcd
# ../RES/point_end/clouds_tof/cloud_0_0007.pcd
# ../RES/point_end/clouds_tof/cloud_0_0078.pcd
# ../RES/point_end/clouds_tof/cloud_0_0071.pcd
# ../RES/point_end/clouds_tof/cloud_0_0027.pcd
# ../RES/point_end/clouds_tof/cloud_0_0086.pcd
# ../RES/point_end/clouds_tof/cloud_0_0076.pcd
# ../RES/point_end/clouds_tof/cloud_0_0089.pcd
# ../RES/point_end/clouds_tof/cloud_0_0091.pcd
# ../RES/point_end/clouds_tof/cloud_0_0059.pcd
# ../RES/point_end/clouds_tof/cloud_0_0021.pcd
# ../RES/point_end/clouds_tof/cloud_0_0100.pcd
# ../RES/point_end/clouds_tof/cloud_0_0042.pcd
# ../RES/point_end/clouds_tof/cloud_0_0087.pcd
# ../RES/point_end/clouds_tof/cloud_0_0018.pcd
# ../RES/point_end/clouds_tof/cloud_0_0024.pcd
# ../RES/point_end/clouds_tof/cloud_0_0017.pcd
# ../RES/point_end/clouds_tof/cloud_0_0073.pcd
